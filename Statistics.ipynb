# %%
import numpy as np
import pandas as pd
import datetime

# %%
import tools
df = tools.load_dataframe()

# %% [markdown]
# # Client flow at specific hours

# %%
import matplotlib.pyplot as plt
scale = df[(df["SUBBRANCH_ID"] == 1006034) & (df["HOUR"] == 8) & (df["OPCAT_CATEGORY"] == "CM")]
plt.plot(scale["DAY"], scale["SIZE"], '.')
plt.show()

# %%
import matplotlib.pyplot as plt
scale = df[(df["SUBBRANCH_ID"] == 1006034) & (df["HOUR"] == 12) & (df["OPCAT_CATEGORY"] == "CM")]
plt.plot(scale["DAY"], scale["SIZE"], '.')
plt.show()

# %%
import matplotlib.pyplot as plt
scale = df[(df["SUBBRANCH_ID"] == 1006034) & (df["HOUR"] == 18) & (df["OPCAT_CATEGORY"] == "CM")]
plt.plot(scale["DAY"], scale["SIZE"], '.')
plt.show()

# %% [markdown]
# # one-month interval

# %%
import datetime
scale = df[(df["SUBBRANCH_ID"] == 1005625) & (df["OPCAT_CATEGORY"] == "CM") & (df["HOUR"] == 18) & 
           (df["DAY"] >= datetime.datetime.strptime("02.09.2014", "%d.%m.%Y").date()) & 
           (df["DAY"] <= datetime.datetime.strptime("02.10.2014", "%d.%m.%Y").date())]
plt.plot(scale["DAY"], scale["SIZE"], '.')
plt.show()

# %%
import datetime
scale = df[(df["SUBBRANCH_ID"] == 1005625) & (df["OPCAT_CATEGORY"] == "CM") & (df["HOUR"] == 18) & 
           (df["DAY"] >= datetime.datetime.strptime("02.03.2014", "%d.%m.%Y").date()) & 
           (df["DAY"] <= datetime.datetime.strptime("02.04.2014", "%d.%m.%Y").date())]
plt.plot(scale["DAY"], scale["SIZE"], '.')
plt.show()

# %%
import datetime
scale = df[(df["SUBBRANCH_ID"] == 1005625) & (df["OPCAT_CATEGORY"] == "CM") & (df["HOUR"] == 18) & 
           (df["DAY"] >= datetime.datetime.strptime("02.03.2015", "%d.%m.%Y").date()) & 
           (df["DAY"] <= datetime.datetime.strptime("02.04.2015", "%d.%m.%Y").date())]
plt.plot(scale["DAY"], scale["SIZE"], '.')
plt.show()

# %% [markdown]
# # one-week interval

# %%
import datetime
scale = df[(df["SUBBRANCH_ID"] == 1005625) & (df["OPCAT_CATEGORY"] == "CM") & (df["HOUR"] == 18) & 
           (df["DAY"] >= datetime.datetime.strptime("06.09.2015", "%d.%m.%Y").date()) & 
           (df["DAY"] <= datetime.datetime.strptime("11.10.2015", "%d.%m.%Y").date())]
plt.plot(scale["DAY"], scale["SIZE"], '.')
plt.show()

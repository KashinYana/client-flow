# %%
import numpy as np
import pandas as pd

# %%
file = 'data.txt'
FIN = open(file, 'r')
data = []

branches = []
categories = []
days = []
hours = []

for line in FIN:
    line = line.strip().split()
    
    branches.append(int(line[0]))
    categories.append(line[1])
    days.append(datetime.datetime.strptime(line[2], "%d.%m.%Y").date())
    hours.append(int(line[3]))

# %%
df = pd.DataFrame({
        "SUBBRANCH_ID":  pd.Series(branches),
        "OPCAT_CATEGORY":  pd.Series(categories),
        "DAY":  pd.Series(days),
        "HOUR":  pd.Series(hours),
    })

# %%
df.head()
# Out:
#           DAY  HOUR OPCAT_CATEGORY  SUBBRANCH_ID
# 0  2013-07-01     8             CM       1005625
# 1  2013-07-01     8             CM       1005625
# 2  2013-07-01     8             CM       1005625
# 3  2013-07-01     8             CM       1005625
# 4  2013-07-01     8             CM       1005625

# %%
scale = df[(df["SUBBRANCH_ID"] == 1005625) & (df["HOUR"] == 11) & (df["DAY"] > )].groupby(["DAY"]).size()

# %%
import matplotlib.pyplot as plt
plt.plot(keys, values)
plt.show()

# %%
import numpy as np
import pandas as pd
import datetime

# %%
import tools
df = tools.load_dataframe()

# %%
import matplotlib.pyplot as plt
scale = df[(df["SUBBRANCH_ID"] == 1006034) & (df["HOUR"] == 18) & (df["OPCAT_CATEGORY"] == "CM")]
plt.plot(scale["DAY"], scale["SIZE"], '.')
plt.show()

# %%
import matplotlib.pyplot as plt
scale = df[(df["SUBBRANCH_ID"] == 1005625) & (df["HOUR"] == 18) & (df["OPCAT_CATEGORY"] == "SM")]
plt.plot(scale["DAY"], scale["SIZE"], '.')
plt.show()

# %%
import datetime
scale = df[(df["SUBBRANCH_ID"] == 1005625) & (df["OPCAT_CATEGORY"] == "CM") & (df["HOUR"] == 11) & 
           (df["DAY"] >= datetime.datetime.strptime("02.03.2015", "%d.%m.%Y").date()) & 
           (df["DAY"] <= datetime.datetime.strptime("02.03.2016", "%d.%m.%Y").date())]
plt.plot(scale["DAY"], scale["SIZE"], '.')
plt.show()

# %%
scale = df[(df["SUBBRANCH_ID"] == 1005625) & (df["HOUR"] == 9) & 
           (df["DAY"] >= datetime.datetime.strptime("23.12.2014", "%d.%m.%Y").date()) & 
           (df["DAY"] <= datetime.datetime.strptime("10.01.2015", "%d.%m.%Y").date())]
plt.plot(scale["DAY"], scale["SIZE"], '.')
plt.show()
